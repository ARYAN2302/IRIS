# %% [markdown]
# # UMAP Visualization Demo
#
# This notebook will be used to inspect embeddings and visualize separation in latent space.

# %%
from pathlib import Path

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
root
